# %%
import pandas as pd
data=pd.read_csv("logistic_regression_dataset.csv")
data
# Out:
#         id  age  education sex is_smoking  cigsPerDay  BPMeds  \
# 0        0   64        2.0   F        YES         3.0     0.0
# 1        1   36        4.0   M         NO         0.0     0.0
# 2        2   46        1.0   F        YES        10.0     0.0
# 3        3   50        1.0   M        YES        20.0     0.0
# 4        4   64        1.0   F        YES        30.0     0.0
# ...    ...  ...        ...  ..        ...         ...     ...
# 4233  4233   46        3.0   F         NO         0.0     0.0
# 4234  4234   58        2.0   F         NO         0.0     0.0
# 4235  4235   55        1.0   M         NO         0.0     0.0
# 4236  4236   45        3.0   F         NO         0.0     0.0
# 4237  4237   56        NaN   M        YES        25.0     0.0
#
#       prevalentStroke  prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  \
# 0                   0             0         0    221.0  148.0   85.0    NaN
# 1                   0             1         0    212.0  168.0   98.0  29.77
# 2                   0             0         0    250.0  116.0   71.0  20.35
# 3                   0             1         0    233.0  158.0   88.0  28.26
# 4                   0             0         0    241.0  136.5   85.0  26.42
# ...               ...           ...       ...      ...    ...    ...    ...
# 4233                0             0         0    277.0  122.5   77.5  27.42
# 4234                0             0         0    190.0  132.0   67.0  23.08
# 4235                0             0         0    199.0  134.0   80.0  26.41
# 4236                0             1         0    231.0  157.5  104.5  22.86
# 4237                0             0         0    255.0  138.0   80.0  23.44
#
#       heartRate  glucose  TenYearCHD
# 0          90.0     80.0         1.0
# 1          72.0     75.0         0.0
# 2          88.0     94.0         0.0
# 3          68.0     94.0         1.0
# 4          70.0     77.0         0.0
# ...         ...      ...         ...
# 4233       63.0     77.0         NaN
# 4234       65.0     70.0         NaN
# 4235      120.0      NaN         NaN
# 4236       75.0     92.0         NaN
# 4237       67.0     79.0         NaN
#
# [4238 rows x 17 columns]

# %%
data.isnull().sum()
# Out:
# id                   0
# age                  0
# education          105
# sex                  0
# is_smoking           0
# cigsPerDay          29
# BPMeds              53
# prevalentStroke      0
# prevalentHyp         0
# diabetes             0
# totChol             50
# sysBP                0
# diaBP                0
# BMI                 19
# heartRate            1
# glucose            388
# TenYearCHD         848
# dtype: int64

# %%
data['education'].fillna(df['education'].mean(),inplace=True)
data
# Out:
#         id  age  education sex is_smoking  cigsPerDay  BPMeds  \
# 0        0   64    2.00000   F        YES         3.0     0.0
# 1        1   36    4.00000   M         NO         0.0     0.0
# 2        2   46    1.00000   F        YES        10.0     0.0
# 3        3   50    1.00000   M        YES        20.0     0.0
# 4        4   64    1.00000   F        YES        30.0     0.0
# ...    ...  ...        ...  ..        ...         ...     ...
# 4233  4233   46    3.00000   F         NO         0.0     0.0
# 4234  4234   58    2.00000   F         NO         0.0     0.0
# 4235  4235   55    1.00000   M         NO         0.0     0.0
# 4236  4236   45    3.00000   F         NO         0.0     0.0
# 4237  4237   56    1.97895   M        YES        25.0     0.0
#
#       prevalentStroke  prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  \
# 0                   0             0         0    221.0  148.0   85.0    NaN
# 1                   0             1         0    212.0  168.0   98.0  29.77
# 2                   0             0         0    250.0  116.0   71.0  20.35
# 3                   0             1         0    233.0  158.0   88.0  28.26
# 4                   0             0         0    241.0  136.5   85.0  26.42
# ...               ...           ...       ...      ...    ...    ...    ...
# 4233                0             0         0    277.0  122.5   77.5  27.42
# 4234                0             0         0    190.0  132.0   67.0  23.08
# 4235                0             0         0    199.0  134.0   80.0  26.41
# 4236                0             1         0    231.0  157.5  104.5  22.86
# 4237                0             0         0    255.0  138.0   80.0  23.44
#
#       heartRate  glucose  TenYearCHD
# 0          90.0     80.0         1.0
# 1          72.0     75.0         0.0
# 2          88.0     94.0         0.0
# 3          68.0     94.0         1.0
# 4          70.0     77.0         0.0
# ...         ...      ...         ...
# 4233       63.0     77.0         NaN
# 4234       65.0     70.0         NaN
# 4235      120.0      NaN         NaN
# 4236       75.0     92.0         NaN
# 4237       67.0     79.0         NaN
#
# [4238 rows x 17 columns]

# %%
data['cigsPerDay'].fillna(data['cigsPerDay'].mean(),inplace=True)

# %%
data['BPMeds'].value_counts()
# Out:
# 0.0    4061
# 1.0     124
# Name: BPMeds, dtype: int64

# %%
data['BPMeds']=data['BPMeds'].fillna(0)

# %%
data['TenYearCHD'].value_counts()
# Out:
# 0.0    2879
# 1.0     511
# Name: TenYearCHD, dtype: int64

# %%
data=data.dropna(subset=['TenYearCH'])
data

# %%
df
# Out:
#         id  age  education sex is_smoking  cigsPerDay  BPMeds  \
# 0        0   64    2.00000   F        YES         3.0     0.0
# 1        1   36    4.00000   M         NO         0.0     0.0
# 2        2   46    1.00000   F        YES        10.0     0.0
# 3        3   50    1.00000   M        YES        20.0     0.0
# 4        4   64    1.00000   F        YES        30.0     0.0
# ...    ...  ...        ...  ..        ...         ...     ...
# 4233  4233   46    3.00000   F         NO         0.0     0.0
# 4234  4234   58    2.00000   F         NO         0.0     0.0
# 4235  4235   55    1.00000   M         NO         0.0     0.0
# 4236  4236   45    3.00000   F         NO         0.0     0.0
# 4237  4237   56    1.97895   M        YES        25.0     0.0
#
#       prevalentStroke  prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  \
# 0                   0             0         0    221.0  148.0   85.0    NaN
# 1                   0             1         0    212.0  168.0   98.0  29.77
# 2                   0             0         0    250.0  116.0   71.0  20.35
# 3                   0             1         0    233.0  158.0   88.0  28.26
# 4                   0             0         0    241.0  136.5   85.0  26.42
# ...               ...           ...       ...      ...    ...    ...    ...
# 4233                0             0         0    277.0  122.5   77.5  27.42
# 4234                0             0         0    190.0  132.0   67.0  23.08
# 4235                0             0         0    199.0  134.0   80.0  26.41
# 4236                0             1         0    231.0  157.5  104.5  22.86
# 4237                0             0         0    255.0  138.0   80.0  23.44
#
#       heartRate  glucose                                         TenYearCHD
# 0          90.0     80.0  <bound method Series.dropna of 0       1.0\n1 ...
# 1          72.0     75.0  <bound method Series.dropna of 0       1.0\n1 ...
# 2          88.0     94.0  <bound method Series.dropna of 0       1.0\n1 ...
# 3          68.0     94.0  <bound method Series.dropna of 0       1.0\n1 ...
# 4          70.0     77.0  <bound method Series.dropna of 0       1.0\n1 ...
# ...         ...      ...                                                ...
# 4233       63.0     77.0  <bound method Series.dropna of 0       1.0\n1 ...
# 4234       65.0     70.0  <bound method Series.dropna of 0       1.0\n1 ...
# 4235      120.0      NaN  <bound method Series.dropna of 0       1.0\n1 ...
# 4236       75.0     92.0  <bound method Series.dropna of 0       1.0\n1 ...
# 4237       67.0     79.0  <bound method Series.dropna of 0       1.0\n1 ...
#
# [4238 rows x 17 columns]
